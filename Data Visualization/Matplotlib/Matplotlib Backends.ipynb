# %% [markdown]
# # Inline: Permitirá ver un gráfico en este notebook debajo de la línea de código que lo invoca

# %%
# %matplotlib inline
import matplotlib.pyplot as plt #Para realizar gráficos sencillos en 2D importaremos el módulo Matplotlib.pyplot

# %%
plt.plot(5,5,'o')
plt.show()

# %% [markdown]
# # Notebook: para obtener una computadora portátil con capacidad de zoom y tamaño

# %%
# %matplotlib notebook
plt.plot(5,5,'o')
# Out:
# <img src="data:image/png;base64,..." width="432">
